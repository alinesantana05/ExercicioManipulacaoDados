# %% [markdown]
# #----- **EXERCÍCIOS**-----

# %% [markdown]
# ## **1. Criando e Explorando DataFrames**
# 1. Crie um **DataFrame** com os seguintes dados para as colunas e preencha as linhas:
#
#    | Nome  | Idade | Cidade           | Salário |
#
#
# 2. Exiba as **5 primeiras linhas** do DataFrame.
# 3. Verifique as **informações gerais** (tipos de dados, valores nulos, etc.).
# 4. Liste apenas os **nomes das colunas**.
#
# ---
#
# ## **2. Filtrando e Modificando Dados**
# 5. Filtre os funcionários que ganham **mais de 4000**.
# 6. Selecione apenas as colunas `Nome` e `Cidade`.
# 7. Adicione uma nova coluna chamada `Experiência (anos)` com os valores `[2, 5, 1, 4, 8]`.
# 8. Substitua todas as ocorrências de `"São Paulo"` por `"SP"` na coluna `Cidade`.
# 9. Remova a coluna `Experiência (anos)`.
#
# ---
#
# ## **3. Estatísticas e Agrupamento**
# 10. Qual é a **média dos salários**?
# 11. Qual é o **maior e o menor salário**?
# 12. Quantas pessoas têm **menos de 30 anos**?
# 13. Agrupe os dados pela coluna `Cidade` e calcule a **média dos salários** por cidade.
#
# ---
#
# ## **4. Manipulação de Dados Faltantes**
# 14. Adicione uma nova linha com os dados: `("Fernando", NaN, "Recife", 3700)`.
# 15. Identifique os valores **faltantes** no DataFrame.
# 16. Substitua a idade ausente pela **média das idades**.
#
# ---
#
# ## **5. Ordenação e Indexação**
# 17. Ordene os dados por `Salário` de forma **decrescente**.
# 18. Defina a coluna `Nome` como **índice** do DataFrame.
# 19. Redefina os índices para números inteiros.
#
# ---
#
# ## **6. Trabalhando com Arquivos CSV e Excel**
# 20. Salve o DataFrame em um arquivo **CSV** chamado `"dados_funcionarios.csv"`.
# 21. Carregue o arquivo CSV e exiba as primeiras 3 linhas.
# 22. Salve o DataFrame em um arquivo **Excel** chamado `"dados.xlsx"` com a planilha nomeada como `"nome"`.
#
# ---
#
# ## **📢 Desafio Extra**
# 📌 **Desafio 1:** Adicione uma nova coluna `Categoria Salarial`, onde:
# - `"Baixo"` se o salário for menor que 3000.
# - `"Médio"` se for entre 3000 e 4500.
# - `"Alto"` se for maior que 4500.
#
#
# ---

# %% [markdown]
# Para criar um DataFrame usá-se:
#
# variável = pd.DataFrame(váriável ou criar um dicionário)

# %%
import pandas as pd

# %%
df = {'Nome' : ['Aline', 'Julia', 'Luisa', 'Ana', 'Maria', 'Luana'],
                  'Idade' : [20, 22, 30, 25, 41, 60],
                   'Cidade' : ['São Paulo', 'Rio de Janeiro', 'Santa Catarina', 'Curitiba', 'Bahia', 'Manaus'],
                   'Salário': [2000, 2700, 3500, 2900, 6000, 4800]}

# %%
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#     Nome  Idade          Cidade  Salário
# 0  Aline     20       São Paulo     2000
# 1  Julia     22  Rio de Janeiro     2700
# 2  Luisa     30  Santa Catarina     3500
# 3    Ana     25        Curitiba     2900
# 4  Maria     41           Bahia     6000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Nome     6 non-null      object
#  1   Idade    6 non-null      int64
#  2   Cidade   6 non-null      object
#  3   Salário  6 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#            Idade      Salário
# count   6.000000     6.000000
# mean   33.000000  3650.000000
# std    15.205262  1486.943173
# min    20.000000  2000.000000
# 25%    22.750000  2750.000000
# 50%    27.500000  3200.000000
# 75%    38.250000  4475.000000
# max    60.000000  6000.000000

# %%
df.columns
# Out:
# Index(['Nome', 'Idade', 'Cidade', 'Salário'], dtype='object')

# %%
salMaior3k = df[df['Salário'] > 3000]

# %%
salMaior3k
# Out:
#     Nome  Idade          Cidade  Salário
# 2  Luisa     30  Santa Catarina     3500
# 4  Maria     41           Bahia     6000
# 5  Luana     60          Manaus     4800

# %%
duascolunas = df[['Nome', 'Cidade']]

# %%
duascolunas
# Out:
#     Nome          Cidade
# 0  Aline       São Paulo
# 1  Julia  Rio de Janeiro
# 2  Luisa  Santa Catarina
# 3    Ana        Curitiba
# 4  Maria           Bahia
# 5  Luana          Manaus

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Experiência'] = [10, 8, 31 ,2, 20, 8]

# %%
df
# Out:
#     Nome  Idade          Cidade  Salário  Experiência
# 0  Aline     20       São Paulo     2000           10
# 1  Julia     22  Rio de Janeiro     2700            8
# 2  Luisa     30  Santa Catarina     3500           31
# 3    Ana     25        Curitiba     2900            2
# 4  Maria     41           Bahia     6000           20
# 5  Luana     60          Manaus     4800            8

# %%
df = pd.DataFrame(df)
df
# Out:
#     Nome  Idade          Cidade  Salário  Experiência
# 0  Aline     20       São Paulo     2000           10
# 1  Julia     22  Rio de Janeiro     2700            8
# 2  Luisa     30  Santa Catarina     3500           31
# 3    Ana     25        Curitiba     2900            2
# 4  Maria     41           Bahia     6000           20
# 5  Luana     60          Manaus     4800            8

# %%
df['Cidade'] = df['Cidade'].replace('São Paulo', 'SP')

# %%
df
# Out:
#     Nome  Idade          Cidade  Salário  Experiência
# 0  Aline     20              SP     2000           10
# 1  Julia     22  Rio de Janeiro     2700            8
# 2  Luisa     30  Santa Catarina     3500           31
# 3    Ana     25        Curitiba     2900            2
# 4  Maria     41           Bahia     6000           20
# 5  Luana     60          Manaus     4800            8

# %%
df = df.drop(columns=['Experiência'])
df
# Out:
#     Nome  Idade          Cidade  Salário
# 0  Aline     20              SP     2000
# 1  Julia     22  Rio de Janeiro     2700
# 2  Luisa     30  Santa Catarina     3500
# 3    Ana     25        Curitiba     2900
# 4  Maria     41           Bahia     6000
# 5  Luana     60          Manaus     4800

# %%
mais4k = df[df['Salário'] > 4000][['Nome', 'Salário']]
mais4k
# Out:
#     Nome  Salário
# 4  Maria     6000
# 5  Luana     4800

# %%
df['Salário'].mean()
# Out:
# 3650.0

# %%
df['Salário'].max()
# Out:
# 6000

# %%
df['Salário'].min()
# Out:
# 2000

# %%
(df['Idade']<30).sum()
# Out:
# 3

# %%
df.groupby('Cidade')['Salário'].mean()
# Out:
# Cidade
# Bahia             6000.0
# Curitiba          2900.0
# Manaus            4800.0
# Rio de Janeiro    2700.0
# SP                2000.0
# Santa Catarina    3500.0
# São Paulo         3650.0
# Name: Salário, dtype: float64

# %%
df.loc[len(df)] = ['Alice', 15, 'São Paulo', 1500]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-c90a7f36be08> in <cell line: 0>()
# ----> 1 df.loc[len(df)] = ['Alice', 15, 'São Paulo', 1500]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     909
#     910         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911         iloc._setitem_with_indexer(indexer, value, self.name)
#     912
#     913     def _validate_key(self, key, axis: AxisInt):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1930
#    1931             if missing:
# -> 1932                 self._setitem_with_indexer_missing(indexer, value)
#    1933                 return
#    1934
#
# ...

# %%
type(df)
df
# Out:
#     Nome  Idade          Cidade  Salário Categoria Salário
# 0  Maria     41           Bahia   6000.0               NaN
# 1  Luana     60          Manaus   4800.0               NaN
# 2  Alice     15       São Paulo   3650.0               NaN
# 3  Luisa     30  Santa Catarina   3500.0               NaN
# 4    Ana     25        Curitiba   2900.0               NaN
# 5  Julia     22  Rio de Janeiro   2700.0               NaN
# 6  Aline     20              SP   2000.0               NaN

# %%
df.at[6, 'Salário'] = pd.NA
df
# Out:
#     Nome  Idade          Cidade  Salário
# 0  Aline     20              SP   2000.0
# 1  Julia     22  Rio de Janeiro   2700.0
# 2  Luisa     30  Santa Catarina   3500.0
# 3    Ana     25        Curitiba   2900.0
# 4  Maria     41           Bahia   6000.0
# 5  Luana     60          Manaus   4800.0
# 6  Alice     15       São Paulo      NaN

# %%
df.isna().sum()
# Out:
# Nome       0
# Idade      0
# Cidade     0
# Salário    1
# dtype: int64

# %%
df['Salário'] = df['Salário'].fillna(df['Salário'].mean())
df
# Out:
#     Nome  Idade          Cidade  Salário
# 0  Aline     20              SP   2000.0
# 1  Julia     22  Rio de Janeiro   2700.0
# 2  Luisa     30  Santa Catarina   3500.0
# 3    Ana     25        Curitiba   2900.0
# 4  Maria     41           Bahia   6000.0
# 5  Luana     60          Manaus   4800.0
# 6  Alice     15       São Paulo   3650.0

# %%
df = df.sort_values(by=['Salário'], ascending=False)

# %%
df
# Out:
#     Nome  Idade          Cidade  Salário
# 4  Maria     41           Bahia   6000.0
# 5  Luana     60          Manaus   4800.0
# 6  Alice     15       São Paulo   3650.0
# 2  Luisa     30  Santa Catarina   3500.0
# 3    Ana     25        Curitiba   2900.0
# 1  Julia     22  Rio de Janeiro   2700.0
# 0  Aline     20              SP   2000.0

# %%
df.to_csv('MeuDataFrame.csv', index=False)
df
# Out:
#     Nome  Idade          Cidade  Salário
# 4  Maria     41           Bahia   6000.0
# 5  Luana     60          Manaus   4800.0
# 6  Alice     15       São Paulo   3650.0
# 2  Luisa     30  Santa Catarina   3500.0
# 3    Ana     25        Curitiba   2900.0
# 1  Julia     22  Rio de Janeiro   2700.0
# 0  Aline     20              SP   2000.0

# %%
df = pd.read_csv('MeuDataFrame.csv')

# %%
df.head(3)
# Out:
#     Nome  Idade     Cidade  Salário
# 0  Maria     41      Bahia   6000.0
# 1  Luana     60     Manaus   4800.0
# 2  Alice     15  São Paulo   3650.0

# %%
df.to_excel('MeuDataFrame.xlsx', index=False)
df
# Out:
#     Nome  Idade          Cidade  Salário Categoria Salário
# 0  Maria     41           Bahia   6000.0               NaN
# 1  Luana     60          Manaus   4800.0               NaN
# 2  Alice     15       São Paulo   3650.0               NaN
# 3  Luisa     30  Santa Catarina   3500.0               NaN
# 4    Ana     25        Curitiba   2900.0               NaN
# 5  Julia     22  Rio de Janeiro   2700.0               NaN
# 6  Aline     20              SP   2000.0               NaN

# %%
df.loc[df['Salário'] < 2500, 'Categoria Salário'] = 'Baixo'
df.loc[df['Salário']> 2500, 'Categoria Salário'] = 'Médio'
df.loc[df['Salário']>=6000, 'Categoria Salário'] = 'Alto'
df
# Out:
#     Nome  Idade          Cidade  Salário Categoria Salário
# 0  Maria     41           Bahia   6000.0              Alto
# 1  Luana     60          Manaus   4800.0             Médio
# 2  Alice     15       São Paulo   3650.0             Médio
# 3  Luisa     30  Santa Catarina   3500.0             Médio
# 4    Ana     25        Curitiba   2900.0             Médio
# 5  Julia     22  Rio de Janeiro   2700.0             Médio
# 6  Aline     20              SP   2000.0             Baixo
